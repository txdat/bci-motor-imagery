# %%
import numpy as np
from scipy import signal
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import plotly.io as pio
import mne
import json
import glob
import os
from tqdm import tqdm
import time
from datetime import timedelta
from braindecode.datasets import BaseConcatDataset
from mne_features.feature_extraction import FeatureExtractor
from pyriemann.estimation import Covariances
from pyriemann.tangentspace import TangentSpace
from pyriemann.classification import TSclassifier, MDM, FgMDM
from pyriemann.utils.distance import distance_riemann, distance_euclid, distance_logeuclid
from pyriemann.utils.mean import mean_riemann, mean_euclid, mean_logeuclid
from sklearn.pipeline import make_pipeline
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import LinearSVC, SVC
from sklearn.manifold import TSNE
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
import sklearn.metrics as metrics
from data_util import load_subjects, load_subject_data, load_data, euclidean_alignment, label_alignment, self_subject_label_alignment, relabel_dataset
from collections import defaultdict
from copy import deepcopy

import warnings
warnings.filterwarnings('ignore')

# %%
# %%time
# fmt: off
subjects = [
    'K001', 'K002', 'K003', 'K004', 'K005', 
    'K006', 'K007', 'K008', 'K009', 'K010', 
    'K011', 'K012', 'K013', 'K015', 'K016', 
    'K017', 'K018', 'K021', 'K022', 'K023', 
    'K024', 'K025', 'K026', 'K027', 'K028', 
    'K300', 'K301', 'K302', 'K303', 'K304', 
    'K305', 'K306', 'K307', 'K308', 'K309', 
    'K310', 'K311', 'K312', 'K313', 'K314', 
    'K315', 'K316', 'K319', 'K320', 'K321', 
    'K322', 'K323', 'K324', 'K325', 'K326', 
    'K327', 'K328', 'K329', 'K330', 'K331', 
    'K332', 'K333', 'K334', 'K335', 'K336', 
    'K337', 'K338', 'K339', 'K342', 'K343', 
    'K344', 'K350', 'K351', 'K352', 'K353', 
    'K354', 'K355', 'K357', 'K358', 'K359', 
    'K360', 'K361', 'K362', 'K364', 'K365', 
    'K366', 'K367', 'K368', 'K369', 'K370', 
    'K371', 'K372', 'K373', 'K374', 'K375',
]

subjects = sorted(subjects)

scenarios = [
    "nâng tay trái",
    "nâng tay phải",
    "nâng chân trái",
    "nâng chân phải",
    # "gật đầu",
    # "lắc đầu",
    # "há miệng",
]

events = [
    "Thinking",
    # "Thinking and Acting",
    "Resting",
    # "Typing",
]

channels = [
    "Fp1", "Fp2",
    "F7", "F3", "Fz", "F4", "F8",
    # "FT9", "FC5", "FC1", "FC2", "FC6", "FT10",
    "FC5", "FC1", "FC2", "FC6",
    "T7", "C3", "Cz", "C4", "T8",
    "CP5", "CP1", "CP2", "CP6",
    "P7", "P3", "Pz", "P4", "P8",
    # "PO9", "O1", "Oz", "O2", "PO10",
    "O1", "Oz", "O2",
]

label_mapping={
    "nâng tay trái_Thinking": "nâng tay trái",
    "nâng tay phải_Thinking": "nâng tay phải",
    # "nâng tay trái_Thinking": "nâng tay",
    # "nâng tay phải_Thinking": "nâng tay",
    # "nâng chân trái_Thinking": "nâng chân trái",
    # "nâng chân phải_Thinking": "nâng chân phải",
    "nâng chân trái_Thinking": "nâng chân",
    "nâng chân phải_Thinking": "nâng chân",
    # "gật đầu_Thinking": "gật đầu",
    # "lắc đầu_Thinking": "lắc đầu",
    "gật đầu_Thinking": "gật/lắc đầu",
    "lắc đầu_Thinking": "gật/lắc đầu",
    "há miệng_Thinking": "há miệng",
    # "nâng tay trái_Thinking and Acting": "nâng tay trái",
    # "nâng tay phải_Thinking and Acting": "nâng tay phải",
    # "nâng chân trái_Thinking and Acting": "nâng chân trái",
    # "nâng chân phải_Thinking and Acting": "nâng chân phải",
    # "gật đầu_Thinking and Acting": "gật đầu",
    # "lắc đầu_Thinking and Acting": "lắc đầu",
    # "há miệng_Thinking and Acting": "há miệng",
    "Resting": "rest",
}

max_duration = {  # seconds
    # "nâng tay trái": 10,
    # "nâng tay phải": 10,
    # "nâng chân trái": 10,
    # "nâng chân phải": 10,
    # "gật đầu": 10,
    # "lắc đầu": 10,
    "rest": 20,
}

n_channels = len(channels)

print(f"using {n_channels} channels")

minimal_trial_duration = 4  # @param
window_duration = 2  # @param
window_stride_duration = 0.5  # @param

fmin = 8.0  # @param
fmax = 30.0  # @param

moving_standardize = False  # @param {"type": "boolean"}

ds = load_data(
    "../data/DataVIN/Official",  
    subjects=subjects,
    scenarios=scenarios,
    events=events,
    channels=channels,
    label_mapping=label_mapping,
    minimal_trial_duration=minimal_trial_duration,
    window_duration=window_duration, 
    window_stride_duration=window_stride_duration, 
    start_offset=0,
    stop_offset=0,
    max_duration=max_duration,
    fmin=fmin, 
    fmax=fmax, 
    moving_standardize=moving_standardize,
    resample=None,
    return_raw=False,
    return_preprocessed=False,
    preload=True,
)

als_subjects = [
    *(f"ALS01_t{i}" for i in range(1, 11)),
    *(f"ALS02_t{i}" for i in range(1, 11)),
    *(f"ALS03_t{i}" for i in range(1, 10)),
    *(f"ALS04_t{i}" for i in range(1, 9)),
    *(f"ALS05_t{i}" for i in range(1, 7)),
    *(f"ALS06_t{i}" for i in range(1, 4)),
]

als_ds = load_data(
    "../data/DataVIN/ALS/als-patients",  
    subjects=als_subjects,
    scenarios=scenarios,
    events=events,
    channels=channels,
    label_mapping=label_mapping,
    minimal_trial_duration=minimal_trial_duration,
    window_duration=window_duration, 
    window_stride_duration=window_stride_duration, 
    start_offset=0,
    stop_offset=0,
    max_duration=max_duration,
    fmin=fmin, 
    fmax=fmax, 
    moving_standardize=moving_standardize,
    resample=None,
    return_raw=False,
    return_preprocessed=False,
    preload=True,
)

# ds = als_ds
# subjects = als_subjects

ds = BaseConcatDataset([ds, als_ds])
subjects.extend(als_subjects)

# fmt: on

ds_info = ds.description

ds_info["epochs"] = 0
for i, r in ds_info.iterrows():
    ds_info.loc[i, "epochs"] = len(ds.datasets[i].windows)

print(f"loaded {len(ds_info['subject'].unique())} subjects - {ds_info['epochs'].sum()} epochs")
ds_info
# Out:
# using 28 channels
# subject: 100%|█████████████████████████████████████████████████████| 106/106 [00:03<00:00, 30.20it/s]
# subject: 100%|███████████████████████████████████████████████████████| 90/90 [00:05<00:00, 15.24it/s]
# trial: 100%|████████████████████████████████████████████████████| 2280/2280 [00:05<00:00, 410.33it/s]
# subject: 100%|███████████████████████████████████████████████████████| 46/46 [00:01<00:00, 23.62it/s]
# subject: 100%|███████████████████████████████████████████████████████| 46/46 [00:02<00:00, 17.97it/s]
# trial: 100%|████████████████████████████████████████████████████| 1041/1041 [00:02<00:00, 368.56it/s]
# loaded 136 subjects - 37236 epochs
# CPU times: user 59.5 s, sys: 3.22 s, total: 1min 2s
# Wall time: 1min 3s
#        subject        scenario     event    onset          label  label_idx  \
# 0         K001   nâng tay trái  Thinking   6.7125  nâng tay trái          3
# 1         K001   nâng tay trái   Resting  13.1479           rest          0
# 2         K001   nâng tay trái   Resting  32.7215           rest          0
# 3         K001   nâng tay trái  Thinking  37.0182  nâng tay trái          3
# 4         K001   nâng tay trái  Thinking  62.7771  nâng tay trái          3
# ...        ...             ...       ...      ...            ...        ...
# 3316  ALS06_t3  nâng chân phải   Resting  19.3768           rest          0
# 3317  ALS06_t3  nâng chân phải  Thinking  26.8445      nâng chân          1
# 3318  ALS06_t3  nâng chân phải   Resting  38.4215           rest          0
# 3319  ALS06_t3  nâng chân phải  Thinking  45.6556      nâng chân          1
# 3320  ALS06_t3  nâng chân phải   Resting  57.3731           rest          0
#
#       trial  split  epochs
# 0         0  train       9
# 1         0  train      10
# 2         1  train       5
# 3         1  train      10
# 4         2  train      10
# ...     ...    ...     ...
# 3316      0  train      11
# 3317      1  train      20
# 3318      1  train      11
# 3319      2  train      20
# 3320      2  train       5
#
# [3321 rows x 9 columns]

# %%
ch_idx = {ch: i for i, ch in enumerate(channels)}

# %%
euclidean_alignment(ds, target_subject=None)
# Out:
# subject: 100%|█████████████████████████████████████████████████████| 136/136 [00:03<00:00, 42.45it/s]

# %%
normal_subject = "K315"
als_subject = "ALS01_t9"

normal_subject_ds = BaseConcatDataset([ds.datasets[i] for i in ds_info[(ds_info["subject"] == normal_subject)].index])
als_subject_ds = BaseConcatDataset([ds.datasets[i] for i in ds_info[(ds_info["subject"] == als_subject)].index])

# %%
label = "rest"
# label = "nâng chân"
# label = "nâng tay phải"
# label = "nâng tay trái"

normal_epochs = mne.concatenate_epochs([_ds.windows for _ds in normal_subject_ds.datasets if _ds.description["label"] == label])
als_epochs = mne.concatenate_epochs([_ds.windows for _ds in als_subject_ds.datasets if _ds.description["label"] == label])

# %%
freqs, normal_psd = signal.welch(normal_epochs.get_data(), fs=128.0, nperseg=128, noverlap=64)
_, als_psd = signal.welch(als_epochs.get_data(), fs=128.0, nperseg=128, noverlap=64)

# %%
for ch_name in ["FC5", "FC1", "FC2", "FC6", "C3", "Cz", "C4", "CP5", "CP1", "CP2", "CP6", "O1", "Oz", "O2"]:
    plt.figure(figsize=(8, 4))

    ch = ch_idx[ch_name]

    # max_psd = max(normal_psd[15, ch].max(), als_psd[15, ch].max())
    max_psd = normal_psd[1, ch].max()

    plt.plot(freqs, normal_psd[1, ch], color='b', lw=1)
    # plt.plot(freqs, als_psd[15, ch], color='r', lw=1)
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Power spectral density (V^2 / Hz)')
    plt.ylim([0, max_psd * 1.1])
    plt.title(f"Welch's periodogram {ch_name} of \"{label}\"")
    plt.xlim([0, freqs.max()])
    
    plt.legend(["normal", "als"])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
normal_subject_ds.description
# Out:
#    subject        scenario     event     onset          label  label_idx  \
# 0     K315   nâng tay trái  Thinking   16.7165  nâng tay trái          3
# 1     K315   nâng tay trái   Resting   23.5314           rest          0
# 2     K315   nâng tay trái   Resting   40.4585           rest          0
# 3     K315   nâng tay trái  Thinking   48.3722  nâng tay trái          3
# 4     K315   nâng tay trái   Resting   56.7036           rest          0
# 5     K315   nâng tay trái   Resting   74.2479           rest          0
# 6     K315   nâng tay trái  Thinking   81.0134  nâng tay trái          3
# 7     K315   nâng tay trái   Resting   88.9264           rest          0
# 8     K315   nâng tay trái   Resting  104.2386           rest          0
# 9     K315   nâng tay phải  Thinking    9.5001  nâng tay phải          2
# 10    K315   nâng tay phải   Resting   16.6656           rest          0
# 11    K315   nâng tay phải   Resting   31.4272           rest          0
# 12    K315   nâng tay phải  Thinking   38.1741  nâng tay phải          2
# 13    K315   nâng tay phải   Resting   46.1551           rest          0
# 14    K315   nâng tay phải   Resting   61.0512           rest          0
# 15    K315   nâng tay phải  Thinking   68.0657  nâng tay phải          2
# 16    K315   nâng tay phải   Resting   75.1628           rest          0
# 17    K315   nâng tay phải   Resting   91.6236           rest          0
# 18    K315  nâng chân trái  Thinking    6.5901      nâng chân          1
# 19    K315  nâng chân trái   Resting   13.2877           rest          0
# 20    K315  nâng chân trái   Resting   27.4671           rest          0
# 21    K315  nâng chân trái  Thinking   32.8473      nâng chân          1
# 22    K315  nâng chân trái   Resting   42.0786           rest          0
# 23    K315  nâng chân trái   Resting   59.1730           rest          0
# 24    K315  nâng chân trái  Thinking   65.7875      nâng chân          1
# 25    K315  nâng chân trái   Resting   73.1350           rest          0
# 26    K315  nâng chân trái   Resting   87.3139           rest          0
# 27    K315  nâng chân phải  Thinking    5.5761      nâng chân          1
# 28    K315  nâng chân phải   Resting   12.4083           rest          0
# 29    K315  nâng chân phải   Resting   26.3036           rest          0
# 30    K315  nâng chân phải  Thinking   33.1511      nâng chân          1
# 31    K315  nâng chân phải   Resting   41.8146           rest          0
# 32    K315  nâng chân phải   Resting   56.3933           rest          0
# 33    K315  nâng chân phải  Thinking   62.7412      nâng chân          1
# 34    K315  nâng chân phải   Resting   70.8883           rest          0
# 35    K315  nâng chân phải   Resting   85.1681           rest          0
#
#     trial  split
# 0       0  train
# 1       0  train
# 2       1  train
# 3       1  train
# 4       2  train
# 5       3  train
# 6       2  train
# 7       4  train
# 8       5  train
# 9       0  train
# 10      0  train
# 11      1  train
# 12      1  train
# 13      2  train
# 14      3  train
# 15      2  train
# 16      4  train
# 17      5  train
# 18      0  train
# 19      0  train
# 20      1  train
# 21      1  train
# 22      2  train
# 23      3  train
# 24      2  train
# 25      4  train
# 26      5  train
# 27      0  train
# 28      0  train
# 29      1  train
# 30      1  train
# 31      2  train
# 32      3  train
# 33      2  train
# 34      4  train
# 35      5  train

# %%
bands = [(8, 12, "Alpha"), (12, 20, "Lower Beta"), (20, 30, "Higher Beta")]

# %%
# %matplotlib widget
normal_epochs.plot_psd_topomap(bands=bands)
# normal_epochs.average().plot_joint(times=np.arange(0, 2, 0.4))
normal_epochs[1].average().plot_topomap(times="interactive", show_names=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
normal_epochs[1].plot_psd(picks=["C3", "Cz", "C4"])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <MNELineFigure size 1000x350 with 2 Axes>
